# %%
#Start by connecting gdrive into the google colab

from google.colab import drive

drive.mount('/content/drive')
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
# import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
# %matplotlib inline
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 14, 8
RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]
# df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/creditcard.csv")
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/data_preprosing_month_hist_encode_standarize_oversample.csv")
.drop(columns=['index','Latitude','Longitude','hist_fraud_trans_24h'])
from sklearn.preprocessing import StandardScaler
data=df.rename(columns={'Fraud':'Class'})
# data = df.drop(['Time'], axis=1)
# data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))
x_train, x_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = x_train[x_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)
x_train_r=x_train.drop(['Class'], axis=1)
y_train_r=x_train['Class']
x_test_r=x_test.drop(['Class'], axis=1)
y_test_r=x_test['Class']


Y_test = x_test['Class']
X_test = x_test.drop(['Class'], axis=1)

x_test = X_test
X_train = X_train.values
X_test = X_test.values
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df
# Out:
#           Amount  Use Chip  ...  hist_trans_24h  hist_trans_avg_amt_60d
# 0      -0.480182       1.0  ...       -1.000000               -1.319448
# 1       0.943202       0.0  ...       -0.666667               -1.054418
# 2       0.002989       0.0  ...       -0.333333               -1.054418
# 3      -0.001218       0.0  ...        0.000000               -1.054418
# 4      -0.453277       0.0  ...        0.333333                0.430091
# ...          ...       ...  ...             ...                     ...
# 429907  1.937112       1.0  ...       -0.666667                0.227854
# 429908 -0.180580       0.0  ...       -0.333333               -0.979133
# 429909  0.634411       0.0  ...       -0.666667                2.385392
# 429910  1.962356       0.0  ...        0.333333                0.275076
# 429911  3.790412       0.0  ...       -0.666667                0.015151
#
# [429912 rows x 12 columns]

# %%
#building the Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier 
#random forest model creation 
# rfc = RandomForestClassifier(n_estimators= 50, max_depth=11,max_features=9,oob_score=True, random_state=10)
rfc = RandomForestClassifier(n_estimators= 50, max_depth=11,max_features=5,oob_score=True, random_state=10)
rfc.fit(x_train_r, y_train_r) 
#predictions 
yPred = rfc.predict(x_test_r)

# %%
#imbalance in the data
fraud = data[data['Class'] == 1] 
valid = data[data['Class'] == 0] 
outlierFraction = len(fraud)/float(len(valid)) 
print(outlierFraction) 
print('Fraud Cases: {}'.format(len(data[data['Class'] == 1]))) 
print('Valid Transactions: {}'.format(len(data[data['Class'] == 0])))
# Out:
# 1.0
# Fraud Cases: 214956
# Valid Transactions: 214956

# %%
#building all kinds of evaluating parameters
from sklearn.metrics import classification_report, accuracy_score  
from sklearn.metrics import precision_score, recall_score 
from sklearn.metrics import f1_score, matthews_corrcoef 
from sklearn.metrics import confusion_matrix 
yTest=y_test_r

n_outliers = len(fraud) 
n_errors = (yPred != yTest).sum() 
print("The model used is Random Forest classifier") 
  
acc = accuracy_score(yTest, yPred) 
print("The accuracy is {}".format(acc)) 
  
prec = precision_score(yTest, yPred) 
print("The precision is {}".format(prec)) 
  
rec = recall_score(yTest, yPred) 
print("The recall is {}".format(rec)) 
  
f1 = f1_score(yTest, yPred) 
print("The F1-Score is {}".format(f1)) 
  
MCC = matthews_corrcoef(yTest, yPred) 
print("The Matthews correlation coefficient is{}".format(MCC))
# Out:
# The model used is Random Forest classifier
# The accuracy is 1.0
# The precision is 1.0
# The recall is 1.0
# The F1-Score is 1.0
# The Matthews correlation coefficient is1.0

# %%
yPred
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
yTest
# Out:
# 43428     1
# 49906     0
# 29474     0
# 276481    0
# 278846    0
#          ..
# 75723     0
# 252263    0
# 221246    0
# 81910     0
# 59490     0
# Name: Class, Length: 56962, dtype: int64

# %% [markdown]
# #导入autoencoder训练好的模型

# %%
# !unzip result\ \(1\).zip
# Out:
# Archive:  result (1).zip
#   inflating: 10.hdf5
#   inflating: 11.hdf5
#   inflating: 12.hdf5
#   inflating: 14.hdf5
#   inflating: 17.hdf5
#   inflating: 18.hdf5
#   inflating: 1.hdf5
#   inflating: 24.hdf5
#   inflating: 26.hdf5
#   inflating: 27.hdf5
#   inflating: 28.hdf5
#   inflating: 2.hdf5
#   inflating: 30.hdf5
#   inflating: 33.hdf5
#   inflating: 38.hdf5
#   inflating: 3.hdf5
#   inflating: 48.hdf5
#   inflating: 4.hdf5
#   inflating: 5.hdf5
#   inflating: 73.hdf5
#   inflating: 7.hdf5
#   inflating: 8.hdf5
#   inflating: 9.hdf5

# %%
# 第一次
import zipfile
from google.colab import drive

drive.mount('/content/drive/')

zip_ref = zipfile.ZipFile("/content/drive/My Drive/Colab Notebooks/result.zip")
zip_ref.extractall()
zip_ref.close()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# 第二次
import zipfile
from google.colab import drive

drive.mount('/content/drive/')

zip_ref = zipfile.ZipFile("/content/drive/My Drive/Colab Notebooks/result_2.zip")
zip_ref.extractall('/content/result_2')
zip_ref.close()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
autoencoder = load_model('67.hdf5')

# %%
autoencoder_2 = load_model('/content/result_2/66.hdf5')

# %%
predictions = autoencoder.predict(x_test_r)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test_r})
threshold = 2.1
# 2.9
def function(a):
	if a>=threshold:
		return 1
	else:
		return 0
# print(frame, '\n')
error_df['pre_true_class'] = error_df.apply(lambda x: function(x.reconstruction_error), axis = 1)
yPred_auto=error_df['pre_true_class']
error_df
yTest=y_test_r
n_outliers = len(fraud) 
n_errors = (yPred_auto != yTest).sum() 
print("The model used is Random Forest classifier") 
  
acc = accuracy_score(yTest, yPred_auto) 
print("The accuracy is {}".format(acc)) 
  
prec = precision_score(yTest, yPred_auto) 
print("The precision is {}".format(prec)) 
  
rec = recall_score(yTest, yPred_auto) 
print("The recall is {}".format(rec)) 
  
f1 = f1_score(yTest, yPred_auto) 
print("The F1-Score is {}".format(f1)) 
  
MCC = matthews_corrcoef(yTest, yPred_auto) 
print("The Matthews correlation coefficient is{}".format(MCC))
# Out:
# The model used is Random Forest classifier
# The accuracy is 0.9932615491490101
# The precision is 0.20454545454545456
# The recall is 0.1925133689839572
# The F1-Score is 0.1983471074380165
# The Matthews correlation coefficient is0.1950571176269971

# %%
predictions = autoencoder_2.predict(x_test_r)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test_r})
threshold = 1
f0=0
while threshold!=11:
    # 2.9
    def function(a):
      if a>=threshold:
        return 1
      else:
        return 0
    # print(frame, '\n')
    error_df['pre_true_class'] = error_df.apply(lambda x: function(x.reconstruction_error), axis = 1)
    yPred_auto=error_df['pre_true_class']
    yTest=y_test_r
    n_outliers = len(fraud) 
    n_errors = (yPred_auto != yTest).sum() 
    f2 = f1_score(yTest, yPred_auto)
    # print("The F1-Score is {}".format(f1))
    if f2>f0:
      f0=f2
      print("The model used is Random Forest classifier")   
      acc = accuracy_score(yTest, yPred_auto) 
      prec = precision_score(yTest, yPred_auto)         
      rec = recall_score(yTest, yPred_auto)         
      f1 = f1_score(yTest, yPred_auto)     
      # print("The F1-Score is {}".format(f1))  
      MCC = matthews_corrcoef(yTest, yPred_auto) 
      threshold_final=threshold
    threshold=threshold+1
print("The threshold is {}".format(threshold_final)) 
print("The accuracy is {}".format(acc)) 
print("The precision is {}".format(prec)) 
print("The recall is {}".format(rec)) 
print("The F1-Score is {}".format(f1)) 
print("The Matthews correlation coefficient is{}".format(MCC))
# Out:
# The model used is Random Forest classifier
# The model used is Random Forest classifier
# The threshold is 2
# The accuracy is 0.9923353016093551
# The precision is 0.18421052631578946
# The recall is 0.22459893048128343
# The F1-Score is 0.20240963855421684
# The Matthews correlation coefficient is0.19958233247254908

# %%
threshold = 1.9
# 2.9
def function(a):
	if a>=threshold:
		return 1
	else:
		return 0
# print(frame, '\n')
error_df['pre_true_class'] = error_df.apply(lambda x: function(x.reconstruction_error), axis = 1)
yPred_auto=error_df['pre_true_class']
error_df
yTest=y_test_r
n_outliers = len(fraud) 
n_errors = (yPred_auto != yTest).sum() 
print("The model used is Random Forest classifier") 
  
acc = accuracy_score(yTest, yPred_auto) 
print("The accuracy is {}".format(acc)) 
  
prec = precision_score(yTest, yPred_auto) 
print("The precision is {}".format(prec)) 
  
rec = recall_score(yTest, yPred_auto) 
print("The recall is {}".format(rec)) 
  
f1 = f1_score(yTest, yPred_auto) 
print("The F1-Score is {}".format(f1)) 
  
MCC = matthews_corrcoef(yTest, yPred_auto) 
print("The Matthews correlation coefficient is{}".format(MCC))
# Out:
# The model used is Random Forest classifier
# The accuracy is 0.9920111149704759
# The precision is 0.184
# The recall is 0.24598930481283424
# The F1-Score is 0.21052631578947367
# The Matthews correlation coefficient is0.20879847892370795

# %%
threshold = 2.1
# 2.9
def function(a):
	if a>=threshold:
		return 1
	else:
		return 0
# print(frame, '\n')
error_df['pre_true_class'] = error_df.apply(lambda x: function(x.reconstruction_error), axis = 1)
yPred_auto=error_df['pre_true_class']
error_df
yTest=y_test_r
n_outliers = len(fraud) 
n_errors = (yPred_auto != yTest).sum() 
print("The model used is Random Forest classifier") 
  
acc = accuracy_score(yTest, yPred_auto) 
print("The accuracy is {}".format(acc)) 
  
prec = precision_score(yTest, yPred_auto) 
print("The precision is {}".format(prec)) 
  
rec = recall_score(yTest, yPred_auto) 
print("The recall is {}".format(rec)) 
  
f1 = f1_score(yTest, yPred_auto) 
print("The F1-Score is {}".format(f1)) 
  
MCC = matthews_corrcoef(yTest, yPred_auto) 
print("The Matthews correlation coefficient is{}".format(MCC))

# %% [markdown]
# # 随机森林调参

# %%
#2.我们首先对n_estimators进行网格搜索：
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import  metrics

param_test1 = {'n_estimators':[50,120,160,200,250]}
gsearch1 = GridSearchCV(estimator = RandomForestClassifier(min_samples_split=100,
                                  min_samples_leaf=20,max_depth=8,max_features='sqrt' ,random_state=10), 
                       param_grid = param_test1, scoring='roc_auc',cv=5)
gsearch1.fit(x_train_r,y_train_r)
print( gsearch1.best_params_, gsearch1.best_score_)#,gsearch1.cv_results_打印拟合结果)
# Out:
# {'n_estimators': 50} 1.0

# %%
#3.接着我们对决策树最大深度max_depth和内部节点再划分所需最小样本数min_samples_split进行网格搜索。
param_test2 = {'max_depth':[1,2,3,5,7,9,11,13]}#, 'min_samples_split':[100,120,150,180,200,300]}
gsearch2 = GridSearchCV(estimator = RandomForestClassifier(n_estimators=50, min_samples_split=100,
                                  min_samples_leaf=20,max_features='sqrt' ,oob_score=True, random_state=10),
   param_grid = param_test2, scoring='roc_auc',iid=False, cv=5)
gsearch2.fit(x_train_r,y_train_r)
print( gsearch2.best_params_, gsearch2.best_score_)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py:823: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   "removed in 0.24.", FutureWarning
# {'max_depth': 5} 1.0

# %%
#4.下面我们再对内部节点再划分所需最小样本数min_samples_split和叶子节点最少样本数min_samples_leaf一起调参。
param_test3 = {'min_samples_split':[80,100,120,140], 'min_samples_leaf':[10,20,30,40,50,100]}
gsearch3 = GridSearchCV(estimator = RandomForestClassifier(n_estimators= 50, max_depth=11,
                                  max_features='sqrt' ,oob_score=True, random_state=10),
   param_grid = param_test3, scoring='roc_auc',iid=False, cv=5)
gsearch3.fit(x_train_r,y_train_r)
print( gsearch3.best_params_, gsearch3.best_score_)
#得到最佳'min_samples_leaf': 10, 'min_samples_split': 80
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-6ca6449856f3> in <module>()
#       4                                   max_features='sqrt' ,oob_score=True, random_state=10),
#       5    param_grid = param_test3, scoring='roc_auc',iid=False, cv=5)
# ----> 6 gsearch3.fit(x_train_r,y_train_r)
#       7 print( gsearch3.best_params_, gsearch3.best_score_)
#       8 #得到最佳'min_samples_leaf': 10, 'min_samples_split': 80
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
# ...

# %%
#5.最后我们再对最大特征数max_features做调参:
param_test4 = {'max_features':[3,5,7,9,11]}
gsearch4 = GridSearchCV(estimator = RandomForestClassifier(n_estimators= 200, max_depth=1,
                                 oob_score=True, random_state=10),
   param_grid = param_test4, scoring='roc_auc',iid=False, cv=5)
gsearch4.fit(x_train_r,y_train_r)
print( gsearch4.best_params_, gsearch4.best_score_)
#得到'max_features': 3
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py:823: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   "removed in 0.24.", FutureWarning
# {'max_features': 11} 0.9994438134926392

# %%
#2.我们首先对n_estimators进行网格搜索：
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import  metrics

param_test1 = {'n_estimators':[50,120,160,200,250]}
gsearch1 = GridSearchCV(estimator = RandomForestClassifier(min_samples_split=100,
                                  min_samples_leaf=20,max_depth=8,max_features='sqrt' ,random_state=10), 
                       param_grid = param_test1, scoring='roc_auc',cv=5)
gsearch1.fit(x_train_r,y_train_r)
print( gsearch1.best_params_, gsearch1.best_score_)#,gsearch1.cv_results_打印拟合结果)
#3.接着我们对决策树最大深度max_depth和内部节点再划分所需最小样本数min_samples_split进行网格搜索。
param_test2 = {'max_depth':[1,2,3,5,7,9,11,13]}#, 'min_samples_split':[100,120,150,180,200,300]}
gsearch2 = GridSearchCV(estimator = RandomForestClassifier(n_estimators=50, min_samples_split=100,
                                  min_samples_leaf=20,max_features='sqrt' ,oob_score=True, random_state=10),
   param_grid = param_test2, scoring='roc_auc',iid=False, cv=5)
gsearch2.fit(x_train_r,y_train_r)
print( gsearch2.best_params_, gsearch2.best_score_)
#5.最后我们再对最大特征数max_features做调参:
param_test4 = {'max_features':[3,5,7,9,11]}
gsearch4 = GridSearchCV(estimator = RandomForestClassifier(n_estimators= 200, max_depth=1,
                                 oob_score=True, random_state=10),
   param_grid = param_test4, scoring='roc_auc',iid=False, cv=5)
gsearch4.fit(x_train_r,y_train_r)
print( gsearch4.best_params_, gsearch4.best_score_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-57c1e2d30829> in <module>()
#      10                                   min_samples_leaf=20,max_depth=8,max_features='sqrt' ,random_state=10),
#      11                        param_grid = param_test1, scoring='roc_auc',cv=5)
# ---> 12 gsearch1.fit(x_train_r,y_train_r)
#      13 print( gsearch1.best_params_, gsearch1.best_score_)#,gsearch1.cv_results_打印拟合结果)
#      14 #3.接着我们对决策树最大深度max_depth和内部节点再划分所需最小样本数min_samples_split进行网格搜索。
#
# NameError: name 'x_train_r' is not defined
